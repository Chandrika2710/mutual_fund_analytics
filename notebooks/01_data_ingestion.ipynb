# %%
import pandas as pd
import requests
from pathlib import Path

# %%
project_root = Path.cwd().parent

raw_path = r"C:\Users\chand\Downloads\mutual_fund_analytics\data\raw"

print("Raw Data Folder:", raw_path)
# Out:
# Raw Data Folder: C:\Users\chand\Downloads\mutual_fund_analytics\data\raw

# %%
fund_master = pd.read_csv(r"C:\Users\chand\Downloads\mutual_fund_analytics\data\raw\01_fund_master.csv")
nav_history = pd.read_csv(r"C:\Users\chand\Downloads\mutual_fund_analytics\data\raw\02_nav_history.csv")
aum = pd.read_csv(r"C:\Users\chand\Downloads\mutual_fund_analytics\data\raw\03_aum_by_fund_house.csv")
sip = pd.read_csv(r"C:\Users\chand\Downloads\mutual_fund_analytics\data\raw\04_monthly_sip_inflows.csv")
category = pd.read_csv(r"C:\Users\chand\Downloads\mutual_fund_analytics\data\raw\05_category_inflows.csv")
folio = pd.read_csv(r"C:\Users\chand\Downloads\mutual_fund_analytics\data\raw\06_industry_folio_count.csv")
performance = pd.read_csv(r"C:\Users\chand\Downloads\mutual_fund_analytics\data\raw\07_scheme_performance.csv")
transactions = pd.read_csv(r"C:\Users\chand\Downloads\mutual_fund_analytics\data\raw\08_investor_transactions.csv")
portfolio = pd.read_csv(r"C:\Users\chand\Downloads\mutual_fund_analytics\data\raw\09_portfolio_holdings.csv")
benchmark = pd.read_csv(r"C:\Users\chand\Downloads\mutual_fund_analytics\data\raw\10_benchmark_indices.csv")

# %%
datasets = {
    "Fund Master": fund_master,
    "NAV History": nav_history,
    "AUM": aum,
    "SIP": sip,
    "Category": category,
    "Folio": folio,
    "Performance": performance,
    "Transactions": transactions,
    "Portfolio": portfolio,
    "Benchmark": benchmark,
}

for name, df in datasets.items():
    print("="*50)
    print(name)
    print("Rows:", df.shape[0])
    print("Columns:", df.shape[1])
# Out:
# ...
# Fund Master
# Rows: 40
# Columns: 15
# ...
# NAV History
# Rows: 42219
# Columns: 3
# ...
# AUM
# Rows: 90
# Columns: 5
# ...
# SIP
# Rows: 48
# Columns: 6
# ...
# Category
# Rows: 144
# Columns: 3
# ...
# Folio
# Rows: 21
# Columns: 6
# ...
# Performance
# Rows: 40
# Columns: 19
# ...
# Transactions
# Rows: 32778
# Columns: 13
# ...
# Portfolio
# Rows: 322
# Columns: 8
# ...
# Benchmark
# Rows: 8050
# Columns: 3

# %%
fund_master.head()
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# ...

# %%
nav_history.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
performance.head()
# Out:
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth  SBI Mutual Fund
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth  SBI Mutual Fund
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth  SBI Mutual Fund
#
#     category     plan  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0  Large Cap  Regular           12.42           12.36           14.45
# 1  Large Cap   Direct           15.25           11.30           14.23
# 2  Small Cap  Regular           24.56           23.39           20.67
# 3  Small Cap   Direct           20.59           23.14           21.82
# 4       Gilt  Regular            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# ...

# %%
transactions.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
schemes = {
    "SBI_Bluechip": 119551,
    "ICICI_Bluechip": 120503,
    "Nippon_LargeCap": 118632,
    "Axis_Bluechip": 119092,
    "Kotak_Bluechip": 120841
}

# %%
for name, code in schemes.items():

    url = f"https://api.mfapi.in/mf/{code}"

    response = requests.get(url)

    if response.status_code == 200:

        data = response.json()

        history = pd.DataFrame(data["data"])

        history["amfi_code"] = code

        history.to_csv(
            r"C:\Users\chand\Downloads\mutual_fund_analytics\data\raw\f"{name}_nav.csv",
            index=False
        )

        print(f"{name} downloaded successfully.")

    else:

        print(f"Unable to download {name}")
# Out:
#   Cell In[27], line 16
#     r"C:\Users\chand\Downloads\mutual_fund_analytics\data\raw\f"{name}_nav.csv",
#                                                                               ^
# SyntaxError: unterminated string literal (detected at line 16)
